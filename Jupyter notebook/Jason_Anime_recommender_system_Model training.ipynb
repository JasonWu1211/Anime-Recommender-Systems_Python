# %% [markdown]
# # YUEHCHAO WU
# # Anime Recommender System
# # Surprise:Model training

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Source-of-Data-:-Kaggle-Anime-Recommendations-Database" data-toc-modified-id="Source-of-Data-:-Kaggle-Anime-Recommendations-Database-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Source of Data : <a href="https://www.kaggle.com/CooperUnion/anime-recommendations-database" target="_blank">Kaggle Anime Recommendations Database</a></a></span></li><li><span><a href="#Import-libraries" data-toc-modified-id="Import-libraries-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Import libraries</a></span></li><li><span><a href="#Load-data" data-toc-modified-id="Load-data-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Load data</a></span></li><li><span><a href="#Configurtion-for-Model-Training" data-toc-modified-id="Configurtion-for-Model-Training-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Configurtion for Model Training</a></span><ul class="toc-item"><li><span><a href="#Confirgure-splite-(5-fold-and-fix-random-state-to-1)" data-toc-modified-id="Confirgure-splite-(5-fold-and-fix-random-state-to-1)-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span><strong>Confirgure splite (5 fold and fix random state to 1)</strong></a></span></li><li><span><a href="#Confirgure-Best_Algo-Function" data-toc-modified-id="Confirgure-Best_Algo-Function-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span><strong>Confirgure Best_Algo Function</strong></a></span></li></ul></li><li><span><a href="#Modeling-Training" data-toc-modified-id="Modeling-Training-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Modeling Training</a></span><ul class="toc-item"><li><span><a href="#KNNWithMeans" data-toc-modified-id="KNNWithMeans-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span><code>KNNWithMeans</code></a></span><ul class="toc-item"><li><span><a href="#buidling-tuned-KNNWithMeans-using-GridSearchCV-on-training-set" data-toc-modified-id="buidling-tuned-KNNWithMeans-using-GridSearchCV-on-training-set-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>buidling tuned <code>KNNWithMeans</code> using GridSearchCV on training set</a></span></li><li><span><a href="#Best-tuned-KNNWithMeans" data-toc-modified-id="Best-tuned-KNNWithMeans-5.1.2"><span class="toc-item-num">5.1.2&nbsp;&nbsp;</span>Best tuned <code>KNNWithMeans</code></a></span></li><li><span><a href="#Prediction-on-testing-set" data-toc-modified-id="Prediction-on-testing-set-5.1.3"><span class="toc-item-num">5.1.3&nbsp;&nbsp;</span>Prediction on testing set</a></span></li><li><span><a href="#Save-result-to-csv" data-toc-modified-id="Save-result-to-csv-5.1.4"><span class="toc-item-num">5.1.4&nbsp;&nbsp;</span>Save result to csv</a></span></li></ul></li><li><span><a href="#SVD" data-toc-modified-id="SVD-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span><code>SVD</code></a></span><ul class="toc-item"><li><span><a href="#buidling-tuned-SVD-using-GridSearchCV-on-training-set" data-toc-modified-id="buidling-tuned-SVD-using-GridSearchCV-on-training-set-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>buidling tuned <code>SVD</code> using GridSearchCV on training set</a></span></li><li><span><a href="#Prediction-on-testing-set" data-toc-modified-id="Prediction-on-testing-set-5.2.2"><span class="toc-item-num">5.2.2&nbsp;&nbsp;</span>Prediction on testing set</a></span></li><li><span><a href="#Save-result-to-csv" data-toc-modified-id="Save-result-to-csv-5.2.3"><span class="toc-item-num">5.2.3&nbsp;&nbsp;</span>Save result to csv</a></span></li></ul></li><li><span><a href="#CoClustering" data-toc-modified-id="CoClustering-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span><code>CoClustering</code></a></span><ul class="toc-item"><li><span><a href="#buidling-tuned-CoClustering-using-GridSearchCV-on-training-set" data-toc-modified-id="buidling-tuned-CoClustering-using-GridSearchCV-on-training-set-5.3.1"><span class="toc-item-num">5.3.1&nbsp;&nbsp;</span>buidling tuned <code>CoClustering</code> using GridSearchCV on training set</a></span></li><li><span><a href="#Prediction-on-testing-set" data-toc-modified-id="Prediction-on-testing-set-5.3.2"><span class="toc-item-num">5.3.2&nbsp;&nbsp;</span>Prediction on testing set</a></span></li><li><span><a href="#Save-result-to-csv" data-toc-modified-id="Save-result-to-csv-5.3.3"><span class="toc-item-num">5.3.3&nbsp;&nbsp;</span>Save result to csv</a></span></li></ul></li><li><span><a href="#SVDpp" data-toc-modified-id="SVDpp-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span><code>SVDpp</code></a></span><ul class="toc-item"><li><span><a href="#buidling-tuned-SVDpp-using-GridSearchCV-on-training-set" data-toc-modified-id="buidling-tuned-SVDpp-using-GridSearchCV-on-training-set-5.4.1"><span class="toc-item-num">5.4.1&nbsp;&nbsp;</span>buidling tuned <code>SVDpp</code> using GridSearchCV on training set</a></span></li></ul></li><li><span><a href="#WeightedHybrid" data-toc-modified-id="WeightedHybrid-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span><code>WeightedHybrid</code></a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Source of Data : [Kaggle Anime Recommendations Database](https://www.kaggle.com/CooperUnion/anime-recommendations-database)

# %% [markdown]
# ## Import libraries

# %%
#standard tools
import pandas as pd
from scipy.stats import ttest_rel,probplot
import numpy as np
from matplotlib import pyplot as plt
import re
import glob
import seaborn as sns
from sklearn.model_selection import train_test_split
from wordcloud import WordCloud
import math
import copy as cp
from collections import defaultdict
import matplotlib.ticker 
sns.set_style('white')


#from surprise
from surprise import KNNWithMeans,SVD,SVDpp,NMF,SlopeOne,CoClustering
from surprise import Reader, Dataset,accuracy
from surprise.model_selection import cross_validate, KFold, ShuffleSplit, GridSearchCV
from surprise.prediction_algorithms import PredictionImpossible
from surprise.model_selection import train_test_split as surprisesplit
from surprise import dump

#user defined functions
from prec_recall import precision_recall_at_k,pr_eval
from sigweight import KNNSigWeighting
from Evaluation_Implemntation import *
from data_cleaning import *
from hybrid import WeightedHybrid

# %% [markdown]
# ## Load data

# %%
#list of anime files
Alst=glob.glob('anime*') 

#load anime files into list of pandas df
Adf=[]
for i in Alst:
    Adf.append(pd.read_csv(i))

Anime = Adf[0]

# %%
#load final form of anime rating data 'core_movie_comedy_rating.csv'
final_form_data=pd.read_csv('core_movie_comedy_rating.csv')

#splittig on final form of data using stratification
train, test = train_test_split(final_form_data, test_size=0.2, random_state=1, 
                               stratify=final_form_data['user_id'])

##write train & test to csv
train.to_csv('train.csv', index=False)
test.to_csv('test.csv', index=False)

# %%
## data for use

#load data into suprise object

reader = Reader(line_format='user item rating', sep=',',rating_scale=(1, 10),skip_lines=1)
WholeSet = Dataset.load_from_file('core_movie_comedy_rating.csv', reader)
S_train = Dataset.load_from_file('train.csv', reader)
S_test = Dataset.load_from_file('test.csv', reader)

# surprise trainset  
trainset = S_train.build_full_trainset() # 80% of data for training
WholeSet_train = WholeSet.build_full_trainset() # wholeSet as training

# testset for evaluating RMSE

testset = list(map(lambda x : x[0:3],S_test.raw_ratings)) # 20% of data as testset for evaluating rmse


# testset for evaluating relevence(Precision, Recall, NDCG)
NoRatingSet = WholeSet_train.build_anti_testset(fill=1) #whole unknown rating

_, noRate_test = train_test_split(NoRatingSet, test_size=0.2, random_state=1, stratify=list(map(lambda x: x[0], NoRatingSet)))

testPlusUnknown= testset + noRate_test #testset + 20% of unknown rating for evaluating relevence

# %% [markdown]
# ## Configurtion for Model Training

# %% [markdown]
# ### __Confirgure splite (5 fold and fix random state to 1)__

# %%
##define kfold with  fold =5 and set random state = 1##
kf_5=KFold(n_splits=5,random_state=1)

# %% [markdown]
# ### __Confirgure Best_Algo Function__

# %%
## configure Best Algo function##
def Best_Algo(algoname,gs_object):
    """
    Args:
        algoname: name of the algorithmn
        gs_object: GridSearchCV object
        
    
    return:
        best_rmses: a pandas series of best RMSES        
        best_estimator: algo with best setting
        results_df: resutls dataframe
    
    print:
        best_rmses
        mean of Best RMSES
        param_grid setting of best_rmses
        index of best rmses in result table
            
    """        
    print('{} Best RMSES: '.format(algoname))
    print('')
    
    results_df = pd.DataFrame(gs_object.cv_results)
    cols=[re.match(r'split\d+_test_rmse', x).group() for x in results_df.columns if re.match(r'split\d+_test_rmse', x)  is not None]
    best_rmses=results_df[cols].iloc[gs_object.best_index.get('rmse'),:] 
    best_params=gs_object.best_params['rmse']
    best_estimator=gs_object.best_estimator['rmse']
    print(best_rmses)
    print('==============================')
    print('mean of Best RMSES: {0:.{1}f}\n'.format(gs_object.best_score['rmse'],3))
    print('best params: {}\n'.format(best_params))
    print('Index: {}\n'.format(gs_object.best_index.get('rmse')))
        
    return best_rmses,best_estimator,results_df

# %% [markdown]
# ## Modeling Training

# %% [markdown]
# *__Model Searching & Parameter Tunung with__ `GridSearchCV `*
# * `KNNWithMeans`
# * `CoClustering`
# * `SVD`
# * `SVDpp`

# %% [markdown]
# ### `KNNWithMeans`

# %% [markdown]
# ####   buidling tuned `KNNWithMeans` using GridSearchCV on training set

# %%
# item based knn gridsearch
par={'k':[5,19,40,95,175],'sim_options':{'name':['pearson','cosine'],'user_based':[False],'min_support':[10,100,200]}}
gs_knn_item = GridSearchCV(KNNWithMeans,par,measures=['rmse'],cv=kf_5,return_train_measures=True)
gs_knn_item.fit(S_train)
# Out:
# Computing the pearson similarity matrix...
# Computing the pearson similarity matrix...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Done computing similarity matrix.
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Done computing similarity matrix.
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Done computing similarity matrix.
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Done computing similarity matrix.

# %%
# user base knn gridsearch
par={'k':[19,40,95,505],'sim_options':{'name':['pearson','cosine'],'user_based':[True],'min_support':[10,100,500]}}
gs_knn_u = GridSearchCV(KNNWithMeans,par,measures=['rmse'],cv=kf_5,return_train_measures=True)
gs_knn_u.fit(S_train)
# Out:
# Computing the pearson similarity matrix...
# Computing the pearson similarity matrix...
# Computing the pearson similarity matrix...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Done computing similarity matrix.
# Done computing similarity matrix.
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Computing the pearson similarity matrix...
# Computing the pearson similarity matrix...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Done computing similarity matrix.
# Done computing similarity matrix.
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Computing the pearson similarity matrix...
# Computing the pearson similarity matrix...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Done computing similarity matrix.
# Done computing similarity matrix.
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Computing the pearson similarity matrix...
# Computing the pearson similarity matrix...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Done computing similarity matrix.
# Done computing similarity matrix.
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Computing the cosine similarity matrix...
# Computing the cosine similarity matrix...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Done computing similarity matrix.
# Done computing similarity matrix.
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Computing the cosine similarity matrix...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Done computing similarity matrix.
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Computing the cosine similarity matrix...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Done computing similarity matrix.
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Computing the pearson similarity matrix...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Done computing similarity matrix.
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Done computing similarity matrix.
# Computing the pearson similarity matrix...

# %% [markdown]
# ####  Best tuned `KNNWithMeans`

# %%
I_Knn_rmses,I_bestKnn,I_knn_result=Best_Algo('KNNWithMeans (item based)',gs_knn_item)
print('\n'*2)
U_Knn_rmses,U_bestKnn,U_knn_result=Best_Algo('KNNWithMeans (user based)',gs_knn_u)
# Out:
# KNNWithMeans (item based) Best RMSES:
#
# split0_test_rmse    1.116829
# split1_test_rmse    1.114835
# split2_test_rmse    1.118085
# split3_test_rmse    1.118635
# split4_test_rmse    1.124152
# Name: 0, dtype: float64
# ==============================
# mean of Best RMSES: 1.119
#
# best params: {'k': 5, 'sim_options': {'name': 'pearson', 'user_based': False, 'min_support': 10}}
#
# Index: 0

# %% [markdown]
# #### Prediction on testing set

# %%
##item base
# fit data with best trained knn
I_bestKnn.fit(trainset)


# bias estimation (Training error)
I_pre_knn=I_bestKnn.test(trainset.build_testset())
print('bias Rmse:',end=' ')
print(accuracy.rmse(I_pre_knn,False))



# unbias estimation (tesing error)
I_pre_knn=I_bestKnn.test(testset)
print('unbias Rmse:',end=' ')
print(accuracy.rmse(I_pre_knn,False))
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# bias Rmse: 0.7000547601466209
# unbias Rmse: 1.0804940549796418

# %% [markdown]
# #### Save result to csv

# %%
#cv best rmse df 
best_rmses_df=pd.DataFrame(I_Knn_rmses) #create df
best_rmses_df.columns=(['Item_knn']) # item base rmses


# save rmses & knn_result_df
I_knn_result.to_csv('I_knn_result.csv')
best_rmses_df.to_csv('best_rmses_df.csv')

# Save prediction & algo
dump.dump('I_knnbestalgo',predictions=I_pre_knn,algo=I_bestKnn)

# %%
# load rmses & knn_result_df
best_rmses_df=pd.read_csv('best_rmses_df.csv',index_col=0)
I_knn_result_df=pd.read_csv('I_knn_result.csv',index_col=0)

# load prediction & algo
I_pre_knn,I_bestKnn = dump.load('I_knnbestalgo')

# %% [markdown]
# ###  `SVD`

# %% [markdown]
# ####   buidling tuned `SVD` using GridSearchCV on training set

# %%
param_grid = {'n_factors':[5,10,300,500],'n_epochs': [5, 20], 'lr_all': [0.002, 0.02,0.2],
              'reg_all': [0.002, 0.02, 0.2, 0.8],'verbose': [True],'random_state': [1]}

svdpp_gs = GridSearchCV(SVD, param_grid, measures=['rmse'],return_train_measures=True, cv=kf_5)

svdpp_gs.fit(S_train)

# %% [markdown]
# #### Prediction on testing set

# %%
##SVD
# fit data with best trained knn
SVD_best.fit(trainset)


# bias estimation (Training error)
bia_pre=SVD_best.test(trainset.build_testset())
print('bias Rmse:',end=' ')
print(accuracy.rmse(bia_pre,False))



# unbias estimation (tesing error)
unbias_pre=SVD_best.test(testset)
print('unbias Rmse:',end=' ')
print(accuracy.rmse(unbias_pre,False))
# Out:
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 10
# Processing epoch 11
# Processing epoch 12
# Processing epoch 13
# Processing epoch 14
# Processing epoch 15
# Processing epoch 16
# Processing epoch 17
# Processing epoch 18
# Processing epoch 19
# bias Rmse: 0.15084563784281416
# unbias Rmse: 1.0472237165064524

# %% [markdown]
# #### Save result to csv

# %%
#add SVD cv best rmse to best_rmses_df
best_rmses_df['SVD']=pd.read_csv('svd_best_rmse.csv',index_col=0).iloc[:5,:]['rmses']



# save rmses & knn_result_df
SVD_result_df.to_csv('svd_results.csv')
best_rmses_df.to_csv('best_rmses_df.csv')

# Save prediction & algo
dump.dump('svd_best',predictions=unbias_pre,algo=SVD_best)

# %%
# load rmses & SVD_result_df
best_rmses_df=pd.read_csv('best_rmses_df.csv',index_col=0)

SVD_result_df=pd.read_csv('svd_results.csv',index_col=0)


# load prediction & algo
SVD_pre,SVD_best = dump.load('svd_best')

# %%
best_rmses_df
# Out:
#                   Item_knn       SVD
# split0_test_rmse  1.116829  1.076326
# split1_test_rmse  1.114835  1.098916
# split2_test_rmse  1.118085  1.093415
# split3_test_rmse  1.118635  1.079043
# split4_test_rmse  1.124152  1.085892

# %% [markdown]
# ###  `CoClustering`

# %% [markdown]
# ####   buidling tuned `CoClustering` using GridSearchCV on training set

# %%
param_grid = {'n_cltr_u':[5,10,100,300,3000], 'n_cltr_i': [5,15,20,150],'n_epochs': [5, 20],
              'verbose': [True],'random_state': [1]}

co_gs = GridSearchCV(CoClustering, param_grid, measures=['rmse'],return_train_measures=True, cv=kf_5)

co_gs.fit(S_train)

# %%
# get the best parameters by rmse and print the results
co_best_rmses,co_estimator, results_df =Best_Algo('CoClustering',co_gs)

# %% [markdown]
# #### Prediction on testing set

# %%
##SVD
# fit data with best trained knn
co_best.fit(trainset)


# bias estimation (Training error)
bia_pre=co_best.test(trainset.build_testset())
print('bias Rmse:',end=' ')
print(accuracy.rmse(bia_pre,False))



# unbias estimation (tesing error)
unbias_pre=co_best.test(testset)
print('unbias Rmse:',end=' ')
print(accuracy.rmse(unbias_pre,False))
# Out:
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 10
# Processing epoch 11
# Processing epoch 12
# Processing epoch 13
# Processing epoch 14
# Processing epoch 15
# Processing epoch 16
# Processing epoch 17
# Processing epoch 18
# Processing epoch 19
# bias Rmse: 1.0199270636526878
# unbias Rmse: 1.161427158979344

# %% [markdown]
# #### Save result to csv

# %%
#add coclustering cv best rmse to best_rmses_df
best_rmses_df['CoClusting']=pd.read_csv('co_best_rmse.csv',index_col=0).iloc[:5,:]['rmses']


# save rmses
best_rmses_df.to_csv('best_rmses_df.csv')

# %%
# load rmses & coclustering_result_df
best_rmse_df=pd.read_csv('co_best_rmse.csv',index_col=0)

co_results_df=pd.read_csv('co_results.csv',index_col=0)


# load prediction & algo
co_pre,co_best = dump.load('co_best')

# %%
best_rmses_df
# Out:
#                   Item_knn       SVD  CoClusting
# split0_test_rmse  1.116829  1.076326    1.190547
# split1_test_rmse  1.114835  1.098916    1.200708
# split2_test_rmse  1.118085  1.093415    1.197391
# split3_test_rmse  1.118635  1.079043    1.196325
# split4_test_rmse  1.124152  1.085892    1.192596

# %% [markdown]
# ### `SVDpp`

# %% [markdown]
# ####   buidling tuned `SVDpp` using GridSearchCV on training set

# %%
param_grid = {'n_factors':[5,10,300,500],'n_epochs': [5, 20], 'lr_all': [0.002, 0.02,0.2],
              'reg_all': [0.002, 0.02, 0.2, 0.8],'verbose': [True],'random_state': [1]}

svdpp_gs = GridSearchCV(SVDpp, param_grid, measures=['rmse'],return_train_measures=True, cv=kf_5)

svdpp_gs.fit(S_train)
# Out:
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 2
#  processing epoch 3
#  processing epoch 4
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 5
#  processing epoch 4
#  processing epoch 5
#  processing epoch 5
#  processing epoch 6
#  processing epoch 5
#  processing epoch 6
#  processing epoch 6
#  processing epoch 7
#  processing epoch 6
#  processing epoch 7
#  processing epoch 7
#  processing epoch 8
#  processing epoch 7
#  processing epoch 8
#  processing epoch 8
#  processing epoch 9
#  processing epoch 8
#  processing epoch 9
#  processing epoch 9
#  processing epoch 10
#  processing epoch 9
#  processing epoch 10
#  processing epoch 10
#  processing epoch 11
#  processing epoch 10
#  processing epoch 11
#  processing epoch 11
#  processing epoch 12
#  processing epoch 11
#  processing epoch 12
#  processing epoch 12
#  processing epoch 13
#  processing epoch 12
#  processing epoch 13
#  processing epoch 13
#  processing epoch 14
#  processing epoch 13
#  processing epoch 14
#  processing epoch 14
#  processing epoch 15
#  processing epoch 14
#  processing epoch 15
#  processing epoch 15
#  processing epoch 16
#  processing epoch 15
#  processing epoch 16
#  processing epoch 16
#  processing epoch 17
#  processing epoch 16
#  processing epoch 17
#  processing epoch 17
#  processing epoch 18
#  processing epoch 17
#  processing epoch 18
#  processing epoch 18
#  processing epoch 19
#  processing epoch 18
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 6
#  processing epoch 6
#  processing epoch 6
#  processing epoch 6
#  processing epoch 7
#  processing epoch 7
#  processing epoch 7
#  processing epoch 7
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 6
#  processing epoch 6
#  processing epoch 6
#  processing epoch 6
#  processing epoch 7
#  processing epoch 7
#  processing epoch 7
#  processing epoch 7
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 6
#  processing epoch 6
#  processing epoch 6
#  processing epoch 6
#  processing epoch 7
#  processing epoch 7
#  processing epoch 7
#  processing epoch 7
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 6
#  processing epoch 6
#  processing epoch 6
#  processing epoch 6
#  processing epoch 7
#  processing epoch 7
#  processing epoch 7
#  processing epoch 7
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 6
#  processing epoch 6
#  processing epoch 6
#  processing epoch 6
#  processing epoch 7
#  processing epoch 7
#  processing epoch 7
#  processing epoch 7
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 6
#  processing epoch 6
#  processing epoch 6
#  processing epoch 6
#  processing epoch 7
#  processing epoch 7
#  processing epoch 7
#  processing epoch 7
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 6
#  processing epoch 6
#  processing epoch 6
#  processing epoch 6
#  processing epoch 7
#  processing epoch 7
#  processing epoch 7
#  processing epoch 7
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 6
#  processing epoch 6
#  processing epoch 6
#  processing epoch 6
#  processing epoch 7
#  processing epoch 7
#  processing epoch 7
#  processing epoch 7
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 19
#  processing epoch 18
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 6
#  processing epoch 6
#  processing epoch 6
#  processing epoch 7
#  processing epoch 6
#  processing epoch 7
#  processing epoch 7
#  processing epoch 8
#  processing epoch 7
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 10
#  processing epoch 9
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 5
#  processing epoch 4
#  processing epoch 5
#  processing epoch 5
#  processing epoch 6
#  processing epoch 5
#  processing epoch 6
#  processing epoch 6
#  processing epoch 7
#  processing epoch 6
#  processing epoch 7
#  processing epoch 7
#  processing epoch 8
#  processing epoch 7
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 10
#  processing epoch 9
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 6
#  processing epoch 6
#  processing epoch 6
#  processing epoch 6
#  processing epoch 7
#  processing epoch 7
#  processing epoch 7
#  processing epoch 7
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 6
#  processing epoch 6
#  processing epoch 6
#  processing epoch 6
#  processing epoch 7
#  processing epoch 7
#  processing epoch 7
#  processing epoch 7
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 6
#  processing epoch 6
#  processing epoch 6
#  processing epoch 6
#  processing epoch 7
#  processing epoch 7
#  processing epoch 7
#  processing epoch 7
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 6
#  processing epoch 6
#  processing epoch 6
#  processing epoch 6
#  processing epoch 7
#  processing epoch 7
#  processing epoch 7
#  processing epoch 7
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 2
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 3
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 4
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 2
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 3
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 4
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 0
#  processing epoch 1
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 2
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 3
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 4
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 5
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 6
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 7
#  processing epoch 6
#  processing epoch 6
#  processing epoch 6
#  processing epoch 8
#  processing epoch 7
#  processing epoch 7
#  processing epoch 7
#  processing epoch 9
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 10
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 11
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 12
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 13
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 14
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 15
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 16
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 17
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 18
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 19
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 2
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 3
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 4
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 5
#  processing epoch 4
#  processing epoch 4
#  processing epoch 5
#  processing epoch 6
#  processing epoch 5
#  processing epoch 5
#  processing epoch 6
#  processing epoch 7
#  processing epoch 6
#  processing epoch 6
#  processing epoch 7
#  processing epoch 8
#  processing epoch 7
#  processing epoch 7
#  processing epoch 8
#  processing epoch 9
#  processing epoch 8
#  processing epoch 8
#  processing epoch 9
#  processing epoch 10
#  processing epoch 9
#  processing epoch 9
#  processing epoch 10
#  processing epoch 11
#  processing epoch 10
#  processing epoch 10
#  processing epoch 11
#  processing epoch 12
#  processing epoch 11
#  processing epoch 11
#  processing epoch 12
#  processing epoch 13
#  processing epoch 12
#  processing epoch 12
#  processing epoch 13
#  processing epoch 14
#  processing epoch 13
#  processing epoch 13
#  processing epoch 14
#  processing epoch 15
#  processing epoch 14
#  processing epoch 14
#  processing epoch 15
#  processing epoch 16
#  processing epoch 15
#  processing epoch 15
#  processing epoch 16
#  processing epoch 17
#  processing epoch 16
#  processing epoch 16
#  processing epoch 17
#  processing epoch 18
#  processing epoch 17
#  processing epoch 17
#  processing epoch 18
#  processing epoch 19
#  processing epoch 18
#  processing epoch 18
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 0
#  processing epoch 0
#  processing epoch 2
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 3
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 4
#  processing epoch 3
#  processing epoch 3
#  processing epoch 5
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 6
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 7
#  processing epoch 6
#  processing epoch 6
#  processing epoch 6
#  processing epoch 8
#  processing epoch 7
#  processing epoch 7
#  processing epoch 7
#  processing epoch 9
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 10
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 11
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 12
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 12
#  processing epoch 13
#  processing epoch 12
#  processing epoch 12
#  processing epoch 13
#  processing epoch 14
#  processing epoch 13
#  processing epoch 13
#  processing epoch 14
#  processing epoch 15
#  processing epoch 14
#  processing epoch 14
#  processing epoch 15
#  processing epoch 16
#  processing epoch 15
#  processing epoch 15
#  processing epoch 16
#  processing epoch 17
#  processing epoch 16
#  processing epoch 16
#  processing epoch 17
#  processing epoch 18
#  processing epoch 17
#  processing epoch 17
#  processing epoch 18
#  processing epoch 19
#  processing epoch 18
#  processing epoch 18
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 2
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 3
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 4
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 5
#  processing epoch 4
#  processing epoch 4
#  processing epoch 5
#  processing epoch 6
#  processing epoch 5
#  processing epoch 5
#  processing epoch 6
#  processing epoch 7
#  processing epoch 6
#  processing epoch 6
#  processing epoch 7
#  processing epoch 8
#  processing epoch 7
#  processing epoch 7
#  processing epoch 8
#  processing epoch 9
#  processing epoch 8
#  processing epoch 8
#  processing epoch 9
#  processing epoch 10
#  processing epoch 9
#  processing epoch 9
#  processing epoch 10
#  processing epoch 11
#  processing epoch 10
#  processing epoch 10
#  processing epoch 11
#  processing epoch 12
#  processing epoch 11
#  processing epoch 11
#  processing epoch 12
#  processing epoch 13
#  processing epoch 12
#  processing epoch 12
#  processing epoch 13
#  processing epoch 14
#  processing epoch 13
#  processing epoch 13
#  processing epoch 14
#  processing epoch 15
#  processing epoch 14
#  processing epoch 14
#  processing epoch 15
#  processing epoch 16
#  processing epoch 15
#  processing epoch 15
#  processing epoch 16
#  processing epoch 17
#  processing epoch 16
#  processing epoch 16
#  processing epoch 17
#  processing epoch 18
#  processing epoch 17
#  processing epoch 17
#  processing epoch 18
#  processing epoch 19
#  processing epoch 18
#  processing epoch 18
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 2
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 3
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 4
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 5
#  processing epoch 4
#  processing epoch 4
#  processing epoch 5
#  processing epoch 6
#  processing epoch 5
#  processing epoch 5
#  processing epoch 6
#  processing epoch 7
#  processing epoch 6
#  processing epoch 6
#  processing epoch 7
#  processing epoch 8
#  processing epoch 7
#  processing epoch 7
#  processing epoch 8
#  processing epoch 9
#  processing epoch 8
#  processing epoch 8
#  processing epoch 9
#  processing epoch 10
#  processing epoch 9
#  processing epoch 9
#  processing epoch 10
#  processing epoch 11
#  processing epoch 10
#  processing epoch 10
#  processing epoch 11
#  processing epoch 12
#  processing epoch 11
#  processing epoch 11
#  processing epoch 12
#  processing epoch 13
#  processing epoch 12
#  processing epoch 12
#  processing epoch 13
#  processing epoch 14
#  processing epoch 13
#  processing epoch 13
#  processing epoch 14
#  processing epoch 15
#  processing epoch 14
#  processing epoch 14
#  processing epoch 15
#  processing epoch 16
#  processing epoch 15
#  processing epoch 15
#  processing epoch 16
#  processing epoch 17
#  processing epoch 16
#  processing epoch 16
#  processing epoch 17
#  processing epoch 18
#  processing epoch 17
#  processing epoch 17
#  processing epoch 18
#  processing epoch 19
#  processing epoch 18
#  processing epoch 18
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 2
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 3
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 4
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 5
#  processing epoch 4
#  processing epoch 4
#  processing epoch 5
#  processing epoch 6
#  processing epoch 5
#  processing epoch 5
#  processing epoch 6
#  processing epoch 7
#  processing epoch 6
#  processing epoch 6
#  processing epoch 7
#  processing epoch 8
#  processing epoch 7
#  processing epoch 7
#  processing epoch 8
#  processing epoch 9
#  processing epoch 8
#  processing epoch 8
#  processing epoch 9
#  processing epoch 10
#  processing epoch 9
#  processing epoch 9
#  processing epoch 10
#  processing epoch 11
#  processing epoch 10
#  processing epoch 10
#  processing epoch 11
#  processing epoch 12
#  processing epoch 11
#  processing epoch 11
#  processing epoch 12
#  processing epoch 13
#  processing epoch 12
#  processing epoch 12
#  processing epoch 13
#  processing epoch 14
#  processing epoch 13
#  processing epoch 13
#  processing epoch 14
#  processing epoch 15
#  processing epoch 14
#  processing epoch 14
#  processing epoch 15
#  processing epoch 16
#  processing epoch 15
#  processing epoch 15
#  processing epoch 16
#  processing epoch 17
#  processing epoch 16
#  processing epoch 16
#  processing epoch 17
#  processing epoch 18
#  processing epoch 17
#  processing epoch 18
#  processing epoch 17
#  processing epoch 19
#  processing epoch 18
#  processing epoch 18
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 0
#  processing epoch 1
#  processing epoch 0
#  processing epoch 2
#  processing epoch 1
#  processing epoch 2
#  processing epoch 1
#  processing epoch 3
#  processing epoch 2
#  processing epoch 3
#  processing epoch 2
#  processing epoch 4
#  processing epoch 3
#  processing epoch 4
#  processing epoch 3
#  processing epoch 5
#  processing epoch 4
#  processing epoch 5
#  processing epoch 4
#  processing epoch 6
#  processing epoch 5
#  processing epoch 6
#  processing epoch 5
#  processing epoch 7
#  processing epoch 6
#  processing epoch 7
#  processing epoch 6
#  processing epoch 8
#  processing epoch 7
#  processing epoch 7
#  processing epoch 8
#  processing epoch 9
#  processing epoch 8
#  processing epoch 8
#  processing epoch 9
#  processing epoch 10
#  processing epoch 9
#  processing epoch 9
#  processing epoch 10
#  processing epoch 11
#  processing epoch 10
#  processing epoch 10
#  processing epoch 11
#  processing epoch 12
#  processing epoch 11
#  processing epoch 11
#  processing epoch 12
#  processing epoch 13
#  processing epoch 12
#  processing epoch 12
#  processing epoch 13
#  processing epoch 14
#  processing epoch 13
#  processing epoch 13
#  processing epoch 14
#  processing epoch 15
#  processing epoch 14
#  processing epoch 14
#  processing epoch 15
#  processing epoch 16
#  processing epoch 15
#  processing epoch 15
#  processing epoch 16
#  processing epoch 17
#  processing epoch 16
#  processing epoch 16
#  processing epoch 17
#  processing epoch 18
#  processing epoch 17
#  processing epoch 17
#  processing epoch 18
#  processing epoch 19
#  processing epoch 18
# ...
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 6
#  processing epoch 6
#  processing epoch 6
#  processing epoch 6
#  processing epoch 7
#  processing epoch 7
#  processing epoch 7
#  processing epoch 7
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 6
#  processing epoch 6
#  processing epoch 6
#  processing epoch 6
#  processing epoch 7
#  processing epoch 7
#  processing epoch 7
#  processing epoch 7
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 6
#  processing epoch 6
#  processing epoch 6
#  processing epoch 6
#  processing epoch 7
#  processing epoch 7
#  processing epoch 7
#  processing epoch 7
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 6
#  processing epoch 6
#  processing epoch 6
#  processing epoch 6
#  processing epoch 7
#  processing epoch 7
#  processing epoch 7
#  processing epoch 7
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 6
#  processing epoch 6
#  processing epoch 6
#  processing epoch 6
#  processing epoch 7
#  processing epoch 7
#  processing epoch 7
#  processing epoch 7
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 6
#  processing epoch 6
#  processing epoch 6
#  processing epoch 6
#  processing epoch 7
#  processing epoch 7
#  processing epoch 7
#  processing epoch 7
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 6
#  processing epoch 6
#  processing epoch 6
#  processing epoch 6
#  processing epoch 7
#  processing epoch 7
#  processing epoch 7
#  processing epoch 7
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 6
#  processing epoch 6
#  processing epoch 6
#  processing epoch 6
#  processing epoch 7
#  processing epoch 7
#  processing epoch 7
#  processing epoch 7
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 3
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 4
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 5
#  processing epoch 6
#  processing epoch 6
#  processing epoch 6
#  processing epoch 6
#  processing epoch 7
#  processing epoch 7
#  processing epoch 7
#  processing epoch 7
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 8
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 9
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 10
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 11
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 12
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 13
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 14
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 15
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 16
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 17
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 18
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 19
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 0
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 1
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2
#  processing epoch 2

# %% [markdown]
# ###  `WeightedHybrid`

# %%
#hybrid_KNN
hybrid  = WeightedHybrid([SVD_best, I_bestKnn])



#RMSE function##
def RMSE_caculator(algoname,algo,data):
    
    print('## {} RMSES: '.format(algoname))
    result=cross_validate(algo, data, measures=['RMSE'], cv=kf_5, verbose=True)
    
    print('=='*50)
    print('')
        
    return result['test_rmse']
    


##compute RMSE for hybrid ##


#hybrid rmse
hybrid_rmses = RMSE_caculator('Weighted Hybrid',hybrid,S_train)
# Out:
# ## Weighted Hybrid RMSES:
# Processing epoch 0
# Processing epoch 0
# Processing epoch 0
# Processing epoch 1
# Processing epoch 0
# Processing epoch 1
# Processing epoch 1
# Processing epoch 2
# Processing epoch 1
# Processing epoch 2
# Processing epoch 2
# Processing epoch 2
# Processing epoch 3
# Processing epoch 3
# Processing epoch 3
# Processing epoch 4
# Processing epoch 3
# Processing epoch 4
# Processing epoch 4
# Processing epoch 4
# Processing epoch 5
# Processing epoch 5
# Processing epoch 5
# Processing epoch 6
# Processing epoch 5
# Processing epoch 6
# Processing epoch 6
# Processing epoch 6
# Processing epoch 7
# Processing epoch 7
# Processing epoch 7
# Processing epoch 8
# Processing epoch 7
# Processing epoch 8
# Processing epoch 8
# Processing epoch 8
# Processing epoch 9
# Processing epoch 9
# Processing epoch 9
# Processing epoch 10
# Processing epoch 9
# Processing epoch 10
# Processing epoch 10
# Processing epoch 10
# Processing epoch 11
# Processing epoch 11
# Processing epoch 11
# Processing epoch 11
# Processing epoch 12
# Processing epoch 12
# Processing epoch 12
# Processing epoch 12
# Processing epoch 13
# Processing epoch 13
# Processing epoch 13
# Processing epoch 13
# Processing epoch 14
# Processing epoch 14
# Processing epoch 14
# Processing epoch 14
# Processing epoch 15
# Processing epoch 15
# Processing epoch 15
# Processing epoch 16
# Processing epoch 15
# Processing epoch 16
# Processing epoch 16
# Processing epoch 16
# Processing epoch 17
# Processing epoch 17
# Processing epoch 17
# Processing epoch 18
# Processing epoch 17
# Processing epoch 18
# Processing epoch 18
# Processing epoch 18
# Processing epoch 19
# Processing epoch 19
# Processing epoch 19
# Processing epoch 19
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Learned weights [1. 0.]
# Learned weights [1. 0.]
# Learned weights [1. 0.]
# Learned weights [1. 0.]
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 10
# Processing epoch 11
# Processing epoch 12
# Processing epoch 13
# Processing epoch 14
# Processing epoch 15
# Processing epoch 16
# Processing epoch 17
# Processing epoch 18
# Processing epoch 19
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Learned weights [1. 0.]
# Evaluating RMSE of algorithm WeightedHybrid on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0929  1.0926  1.0894  1.0913  1.0993  1.0931  0.0034
# Fit time          93.70   94.09   93.94   93.51   42.50   83.55   20.53
# Test time         4.96    6.02    5.82    5.42    2.03    4.85    1.45
# ====================================================================================================

# %%
hybrid_rmses.mean()
# Out:
# 1.0930929022436433
